# %%
import pickle
import string
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt

nltk.download("stopwords")
stop_words = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tirupati\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
model = pickle.load(open("model.pkl", "rb"))
tfidf = pickle.load(open("tfidf.pkl", "rb"))

print("Model & Vectorizer loaded successfully!")
# Out:
# Model & Vectorizer loaded successfully!

# %%
def clean_text(text):
    text = str(text).lower()
    text = "".join([c for c in text if c not in string.punctuation])
    words = text.split()
    words = [word for word in words if word not in stop_words]
    return " ".join(words)

# %%
article = input("Enter news article text:\n")

cleaned = clean_text(article)
vector = tfidf.transform([cleaned])
prediction = model.predict(vector)[0]

# Create graph
fig, ax = plt.subplots(figsize=(4,4))

if prediction == 1:
    color = 'green'
    label = 'Real News'
else:
    color = 'red'
    label = 'Fake News'

# Draw circle
circle = plt.Circle((0.5, 0.6), 0.2, color=color)
ax.add_artist(circle)

# Add text below circle
ax.text(0.5, 0.25, label, fontsize=16, ha='center')

# Remove axes
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_aspect('equal')

plt.title("Prediction Result")
plt.show()
